# %%
from preprocess import preprocess_data_flat
import pandas as pd
from sklearn.model_selection import train_test_split
from lazypredict.Supervised import LazyClassifier

# %%
df_final = [preprocess_data_flat(x, 30) for x in ["1", "2"]]
x_final, y_final = [pd.concat([x[i] for x in df_final], ignore_index=True) for i in range(2)]
X_train_flat, X_test_flat, y_train_flat, y_test_flat = train_test_split(
    x_final.to_numpy(), y_final.to_numpy(), test_size=0.2, random_state=123
)

clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)
models, predictions = clf.fit(X_train_flat, X_test_flat, y_train_flat, y_test_flat)

# %%
models
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# ExtraTreesClassifier               0.89               0.87     0.87      0.89
# RandomForestClassifier             0.89               0.86     0.86      0.89
# LGBMClassifier                     0.86               0.85     0.85      0.86
# XGBClassifier                      0.86               0.84     0.84      0.86
# AdaBoostClassifier                 0.85               0.82     0.82      0.85
# BaggingClassifier                  0.82               0.81     0.81      0.82
# DecisionTreeClassifier             0.80               0.78     0.78      0.80
# KNeighborsClassifier               0.81               0.78     0.78      0.80
# NuSVC                              0.82               0.77     0.77      0.80
# RidgeClassifierCV                  0.77               0.76     0.76      0.77
# LogisticRegression                 0.76               0.75     0.75      0.76
# ExtraTreeClassifier                0.74               0.74     0.74      0.74
# SVC                                0.78               0.73     0.73      0.77
# LinearSVC                          0.72               0.72     0.72      0.72
# RidgeClassifier                    0.70               0.70     0.70      0.70
# Perceptron                         0.71               0.69     0.69      0.71
# SGDClassifier                      0.71               0.68     0.68      0.70
# PassiveAggressiveClassifier        0.68               0.67     0.67      0.68
# CalibratedClassifierCV             0.70               0.64     0.64      0.67
# GaussianNB                         0.54               0.60     0.60      0.51
# LinearDiscriminantAnalysis         0.60               0.60     0.60      0.61
# NearestCentroid                    0.55               0.58     0.58      0.54
# BernoulliNB                        0.55               0.56     0.56      0.55
# LabelPropagation                   0.40               0.50     0.50      0.23
# DummyClassifier                    0.60               0.50     0.50      0.45
# LabelSpreading                     0.40               0.50     0.50      0.23
# QuadraticDiscriminantAnalysis      0.43               0.46     0.46      0.42
#
#                                Time Taken
# Model
# ExtraTreesClassifier                 0.09
# RandomForestClassifier               0.32
# LGBMClassifier                       0.13
# XGBClassifier                        0.79
# AdaBoostClassifier                   0.59
# BaggingClassifier                    0.49
# DecisionTreeClassifier               0.11
# KNeighborsClassifier                 0.03
# NuSVC                                0.03
# RidgeClassifierCV                    0.13
# LogisticRegression                   0.02
# ExtraTreeClassifier                  0.01
# SVC                                  0.03
# LinearSVC                            0.09
# RidgeClassifier                      0.02
# Perceptron                           0.01
# SGDClassifier                        0.06
# PassiveAggressiveClassifier          0.01
# CalibratedClassifierCV               0.25
# GaussianNB                           0.01
# LinearDiscriminantAnalysis           0.35
# NearestCentroid                      0.04
# BernoulliNB                          0.01
# LabelPropagation                     0.02
# DummyClassifier                      0.01
# LabelSpreading                       0.02
# QuadraticDiscriminantAnalysis        0.06
